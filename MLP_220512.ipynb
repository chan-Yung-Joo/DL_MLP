# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import random
import sklearn
import tensorflow as tf

# %%
from sklearn.datasets import load_boston, load_breast_cancer

# %%
random_seed = 20220512
random.seed = random_seed

np.random.seed = random_seed
#tf.random.set_seed(random_seed)

# %%
boston = load_boston() # boston은 Dictionary 형태

# %%
X = pd.DataFrame(boston['data'], columns = boston['feature_names']) # Dictionary 형태를 DataFrame 형태로 변환

# %%
Y = boston['target']

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
import tensorflow.keras as keras

# %% [markdown]
# ---

# %%
Train_X, Test_X, Train_Y, Test_Y = train_test_split(X, Y, test_size = 0.25, random_state = random_seed)

# %%
scaler_X = MinMaxScaler()
scaler_Y = MinMaxScaler()

# %%
scaler_X.fit(Train_X)
scaler_Y.fit(Train_Y.reshape(-1,1))
# Out:
# MinMaxScaler()

# %%
Scaled_Train_X = scaler_X.transform(Train_X)
Scaled_Train_Y = scaler_Y.transform(Train_Y.reshape(-1,1))

Scaled_Test_X = scaler_X.transform(Test_X)

# %% [markdown]
# ----
# ## Deep Learning Framework 사용

# %%
tf.random.set_seed(random_seed)
model = keras.Sequential()

model.add(keras.layers.Dense(units = 10, input_shape = (13, ), activation = 'sigmoid'))
model.add(keras.layers.Dense(units = 5, activation = 'sigmoid'))
model.add(keras.layers.Dense(units = 1 , activation = 'linear'))

lr = 0.3
model.compile(loss = 'mse', optimizer = keras.optimizers.SGD(learning_rate = lr))

non_scale_history = model.fit(Train_X, Train_Y, batch_size = 32, epochs = 200, shuffle = True, verbose = 2 ,validation_split = 0.2) 
# verbose=0,1,2중 선택
# validation_split -> validation 데이터의 비율을 결정
# Out:
# Epoch 1/200
# 10/10 - 0s - loss: 183.5725 - val_loss: 90.9466 - 219ms/epoch - 22ms/step
# Epoch 2/200
# 10/10 - 0s - loss: 118.7553 - val_loss: 117.9702 - 29ms/epoch - 3ms/step
# Epoch 3/200
# 10/10 - 0s - loss: 109.0568 - val_loss: 88.6212 - 16ms/epoch - 2ms/step
# Epoch 4/200
# 10/10 - 0s - loss: 131.1801 - val_loss: 103.7686 - 17ms/epoch - 2ms/step
# Epoch 5/200
# 10/10 - 0s - loss: 116.5058 - val_loss: 92.4663 - 32ms/epoch - 3ms/step
# Epoch 6/200
# 10/10 - 0s - loss: 95.2425 - val_loss: 89.2447 - 16ms/epoch - 2ms/step
# Epoch 7/200
# 10/10 - 0s - loss: 97.7115 - val_loss: 120.7741 - 16ms/epoch - 2ms/step
# Epoch 8/200
# 10/10 - 0s - loss: 132.5546 - val_loss: 99.5618 - 17ms/epoch - 2ms/step
# Epoch 9/200
# 10/10 - 0s - loss: 134.2234 - val_loss: 170.9420 - 17ms/epoch - 2ms/step
# Epoch 10/200
# 10/10 - 0s - loss: 152.5479 - val_loss: 90.2813 - 19ms/epoch - 2ms/step
# Epoch 11/200
# 10/10 - 0s - loss: 100.7697 - val_loss: 97.1999 - 16ms/epoch - 2ms/step
# Epoch 12/200
# 10/10 - 0s - loss: 98.5164 - val_loss: 88.4813 - 16ms/epoch - 2ms/step
# Epoch 13/200
# 10/10 - 0s - loss: 96.3736 - val_loss: 109.5492 - 17ms/epoch - 2ms/step
# Epoch 14/200
# 10/10 - 0s - loss: 104.5190 - val_loss: 103.0257 - 32ms/epoch - 3ms/step
# Epoch 15/200
# 10/10 - 0s - loss: 103.0913 - val_loss: 93.8375 - 17ms/epoch - 2ms/step
# Epoch 16/200
# 10/10 - 0s - loss: 100.2739 - val_loss: 89.7174 - 16ms/epoch - 2ms/step
# Epoch 17/200
# 10/10 - 0s - loss: 95.6390 - val_loss: 102.2027 - 17ms/epoch - 2ms/step
# Epoch 18/200
# 10/10 - 0s - loss: 95.9865 - val_loss: 105.2210 - 17ms/epoch - 2ms/step
# Epoch 19/200
# 10/10 - 0s - loss: 100.5088 - val_loss: 131.1390 - 20ms/epoch - 2ms/step
# Epoch 20/200
# 10/10 - 0s - loss: 97.6739 - val_loss: 103.3821 - 16ms/epoch - 2ms/step
# Epoch 21/200
# 10/10 - 0s - loss: 94.1185 - val_loss: 88.4656 - 17ms/epoch - 2ms/step
# Epoch 22/200
# 10/10 - 0s - loss: 99.2357 - val_loss: 131.8217 - 17ms/epoch - 2ms/step
# Epoch 23/200
# 10/10 - 0s - loss: 101.0524 - val_loss: 88.2432 - 32ms/epoch - 3ms/step
# Epoch 24/200
# 10/10 - 0s - loss: 95.7133 - val_loss: 89.9684 - 17ms/epoch - 2ms/step
# Epoch 25/200
# 10/10 - 0s - loss: 96.3493 - val_loss: 105.2687 - 16ms/epoch - 2ms/step
# Epoch 26/200
# 10/10 - 0s - loss: 111.3135 - val_loss: 120.3369 - 17ms/epoch - 2ms/step
# Epoch 27/200
# 10/10 - 0s - loss: 104.2110 - val_loss: 100.6845 - 17ms/epoch - 2ms/step
# Epoch 28/200
# 10/10 - 0s - loss: 101.8068 - val_loss: 88.5545 - 34ms/epoch - 3ms/step
# Epoch 29/200
# 10/10 - 0s - loss: 97.1194 - val_loss: 88.4743 - 16ms/epoch - 2ms/step
# Epoch 30/200
# 10/10 - 0s - loss: 100.0869 - val_loss: 91.3061 - 17ms/epoch - 2ms/step
# Epoch 31/200
# 10/10 - 0s - loss: 96.5291 - val_loss: 93.3846 - 17ms/epoch - 2ms/step
# Epoch 32/200
# 10/10 - 0s - loss: 106.2073 - val_loss: 94.5738 - 31ms/epoch - 3ms/step
# Epoch 33/200
# 10/10 - 0s - loss: 99.5363 - val_loss: 88.3668 - 18ms/epoch - 2ms/step
# Epoch 34/200
# 10/10 - 0s - loss: 98.2960 - val_loss: 90.1794 - 16ms/epoch - 2ms/step
# Epoch 35/200
# 10/10 - 0s - loss: 96.0774 - val_loss: 111.6257 - 17ms/epoch - 2ms/step
# Epoch 36/200
# 10/10 - 0s - loss: 108.8281 - val_loss: 89.5109 - 17ms/epoch - 2ms/step
# Epoch 37/200
# 10/10 - 0s - loss: 96.1813 - val_loss: 90.8502 - 32ms/epoch - 3ms/step
# Epoch 38/200
# 10/10 - 0s - loss: 96.3895 - val_loss: 88.4157 - 22ms/epoch - 2ms/step
# Epoch 39/200
# 10/10 - 0s - loss: 100.9267 - val_loss: 91.1903 - 11ms/epoch - 1ms/step
# Epoch 40/200
# 10/10 - 0s - loss: 97.7039 - val_loss: 88.5520 - 17ms/epoch - 2ms/step
# Epoch 41/200
# 10/10 - 0s - loss: 101.4810 - val_loss: 88.7163 - 34ms/epoch - 3ms/step
# Epoch 42/200
# 10/10 - 0s - loss: 98.7907 - val_loss: 88.9888 - 16ms/epoch - 2ms/step
# Epoch 43/200
# 10/10 - 0s - loss: 98.7340 - val_loss: 101.3600 - 16ms/epoch - 2ms/step
# Epoch 44/200
# 10/10 - 0s - loss: 101.9076 - val_loss: 144.7498 - 17ms/epoch - 2ms/step
# Epoch 45/200
# 10/10 - 0s - loss: 107.7283 - val_loss: 93.2925 - 33ms/epoch - 3ms/step
# Epoch 46/200
# 10/10 - 0s - loss: 95.4166 - val_loss: 88.2428 - 16ms/epoch - 2ms/step
# Epoch 47/200
# 10/10 - 0s - loss: 96.2448 - val_loss: 118.1080 - 17ms/epoch - 2ms/step
# Epoch 48/200
# 10/10 - 0s - loss: 100.3559 - val_loss: 93.7507 - 17ms/epoch - 2ms/step
# Epoch 49/200
# 10/10 - 0s - loss: 99.3618 - val_loss: 109.5233 - 19ms/epoch - 2ms/step
# Epoch 50/200
# 10/10 - 0s - loss: 101.4908 - val_loss: 94.5895 - 16ms/epoch - 2ms/step
# Epoch 51/200
# 10/10 - 0s - loss: 98.9569 - val_loss: 90.8596 - 17ms/epoch - 2ms/step
# Epoch 52/200
# 10/10 - 0s - loss: 94.8140 - val_loss: 88.5602 - 17ms/epoch - 2ms/step
# Epoch 53/200
# 10/10 - 0s - loss: 97.0207 - val_loss: 88.9026 - 34ms/epoch - 3ms/step
# Epoch 54/200
# 10/10 - 0s - loss: 100.4421 - val_loss: 90.8731 - 17ms/epoch - 2ms/step
# Epoch 55/200
# 10/10 - 0s - loss: 98.4111 - val_loss: 88.2539 - 16ms/epoch - 2ms/step
# Epoch 56/200
# 10/10 - 0s - loss: 101.0015 - val_loss: 113.4297 - 17ms/epoch - 2ms/step
# Epoch 57/200
# 10/10 - 0s - loss: 104.7852 - val_loss: 88.4138 - 33ms/epoch - 3ms/step
# Epoch 58/200
# 10/10 - 0s - loss: 101.7476 - val_loss: 88.2377 - 21ms/epoch - 2ms/step
# Epoch 59/200
# 10/10 - 0s - loss: 101.0368 - val_loss: 105.8357 - 20ms/epoch - 2ms/step
# Epoch 60/200
# 10/10 - 0s - loss: 100.0237 - val_loss: 122.4366 - 8ms/epoch - 847us/step
# Epoch 61/200
# 10/10 - 0s - loss: 102.6656 - val_loss: 88.2545 - 31ms/epoch - 3ms/step
# Epoch 62/200
# 10/10 - 0s - loss: 96.1841 - val_loss: 95.2427 - 18ms/epoch - 2ms/step
# Epoch 63/200
# 10/10 - 0s - loss: 97.2869 - val_loss: 88.5642 - 16ms/epoch - 2ms/step
# Epoch 64/200
# 10/10 - 0s - loss: 108.6248 - val_loss: 88.2553 - 17ms/epoch - 2ms/step
# Epoch 65/200
# 10/10 - 0s - loss: 102.7577 - val_loss: 93.5319 - 17ms/epoch - 2ms/step
# Epoch 66/200
# 10/10 - 0s - loss: 100.3947 - val_loss: 88.8944 - 30ms/epoch - 3ms/step
# Epoch 67/200
# 10/10 - 0s - loss: 97.8499 - val_loss: 96.4131 - 19ms/epoch - 2ms/step
# Epoch 68/200
# 10/10 - 0s - loss: 101.2869 - val_loss: 88.3184 - 16ms/epoch - 2ms/step
# Epoch 69/200
# 10/10 - 0s - loss: 96.6575 - val_loss: 93.1201 - 17ms/epoch - 2ms/step
# Epoch 70/200
# 10/10 - 0s - loss: 104.3779 - val_loss: 92.1332 - 17ms/epoch - 2ms/step
# Epoch 71/200
# 10/10 - 0s - loss: 100.9100 - val_loss: 90.5780 - 32ms/epoch - 3ms/step
# Epoch 72/200
# 10/10 - 0s - loss: 99.9636 - val_loss: 100.3555 - 19ms/epoch - 2ms/step
# Epoch 73/200
# 10/10 - 0s - loss: 99.5738 - val_loss: 88.3888 - 15ms/epoch - 1ms/step
# Epoch 74/200
# 10/10 - 0s - loss: 98.4916 - val_loss: 121.0659 - 17ms/epoch - 2ms/step
# Epoch 75/200
# 10/10 - 0s - loss: 102.9729 - val_loss: 92.3509 - 17ms/epoch - 2ms/step
# Epoch 76/200
# 10/10 - 0s - loss: 96.5218 - val_loss: 92.2387 - 31ms/epoch - 3ms/step
# Epoch 77/200
# 10/10 - 0s - loss: 97.5619 - val_loss: 96.3095 - 17ms/epoch - 2ms/step
# Epoch 78/200
# 10/10 - 0s - loss: 95.3821 - val_loss: 93.6233 - 25ms/epoch - 2ms/step
# Epoch 79/200
# 10/10 - 0s - loss: 98.2384 - val_loss: 88.4565 - 8ms/epoch - 802us/step
# Epoch 80/200
# 10/10 - 0s - loss: 97.3008 - val_loss: 88.2378 - 31ms/epoch - 3ms/step
# Epoch 81/200
# 10/10 - 0s - loss: 97.9177 - val_loss: 93.1565 - 18ms/epoch - 2ms/step
# Epoch 82/200
# 10/10 - 0s - loss: 99.9075 - val_loss: 108.6381 - 16ms/epoch - 2ms/step
# Epoch 83/200
# 10/10 - 0s - loss: 98.7646 - val_loss: 93.4971 - 17ms/epoch - 2ms/step
# Epoch 84/200
# 10/10 - 0s - loss: 98.6077 - val_loss: 88.5991 - 31ms/epoch - 3ms/step
# Epoch 85/200
# 10/10 - 0s - loss: 97.7410 - val_loss: 91.8958 - 18ms/epoch - 2ms/step
# Epoch 86/200
# 10/10 - 0s - loss: 99.6942 - val_loss: 88.2409 - 16ms/epoch - 2ms/step
# Epoch 87/200
# 10/10 - 0s - loss: 97.2391 - val_loss: 114.3504 - 17ms/epoch - 2ms/step
# Epoch 88/200
# 10/10 - 0s - loss: 118.0275 - val_loss: 105.6874 - 17ms/epoch - 2ms/step
# Epoch 89/200
# 10/10 - 0s - loss: 108.7470 - val_loss: 88.3248 - 19ms/epoch - 2ms/step
# Epoch 90/200
# 10/10 - 0s - loss: 95.5725 - val_loss: 90.3513 - 16ms/epoch - 2ms/step
# Epoch 91/200
# 10/10 - 0s - loss: 103.0011 - val_loss: 103.9121 - 16ms/epoch - 2ms/step
# Epoch 92/200
# 10/10 - 0s - loss: 99.2538 - val_loss: 96.6786 - 17ms/epoch - 2ms/step
# Epoch 93/200
# 10/10 - 0s - loss: 97.9774 - val_loss: 99.1679 - 31ms/epoch - 3ms/step
# Epoch 94/200
# 10/10 - 0s - loss: 98.0682 - val_loss: 88.4161 - 18ms/epoch - 2ms/step
# Epoch 95/200
# 10/10 - 0s - loss: 96.6925 - val_loss: 89.7567 - 16ms/epoch - 2ms/step
# Epoch 96/200
# 10/10 - 0s - loss: 110.2529 - val_loss: 92.1914 - 17ms/epoch - 2ms/step
# Epoch 97/200
# 10/10 - 0s - loss: 100.9988 - val_loss: 90.4784 - 17ms/epoch - 2ms/step
# Epoch 98/200
# 10/10 - 0s - loss: 97.4394 - val_loss: 88.7196 - 32ms/epoch - 3ms/step
# Epoch 99/200
# 10/10 - 0s - loss: 99.7545 - val_loss: 103.1976 - 16ms/epoch - 2ms/step
# Epoch 100/200
# 10/10 - 0s - loss: 98.9655 - val_loss: 123.8835 - 17ms/epoch - 2ms/step
# Epoch 101/200
# 10/10 - 0s - loss: 109.3192 - val_loss: 97.9118 - 17ms/epoch - 2ms/step
# Epoch 102/200
# 10/10 - 0s - loss: 98.3465 - val_loss: 92.4414 - 32ms/epoch - 3ms/step
# Epoch 103/200
# 10/10 - 0s - loss: 109.6619 - val_loss: 114.2417 - 16ms/epoch - 2ms/step
# Epoch 104/200
# 10/10 - 0s - loss: 105.2497 - val_loss: 88.5395 - 17ms/epoch - 2ms/step
# Epoch 105/200
# 10/10 - 0s - loss: 97.6160 - val_loss: 104.4427 - 17ms/epoch - 2ms/step
# Epoch 106/200
# 10/10 - 0s - loss: 102.0574 - val_loss: 89.1586 - 31ms/epoch - 3ms/step
# Epoch 107/200
# 10/10 - 0s - loss: 99.3304 - val_loss: 91.0221 - 18ms/epoch - 2ms/step
# Epoch 108/200
# 10/10 - 0s - loss: 98.8666 - val_loss: 97.1990 - 16ms/epoch - 2ms/step
# Epoch 109/200
# 10/10 - 0s - loss: 98.5501 - val_loss: 148.6839 - 17ms/epoch - 2ms/step
# Epoch 110/200
# 10/10 - 0s - loss: 106.8588 - val_loss: 99.5377 - 17ms/epoch - 2ms/step
# Epoch 111/200
# 10/10 - 0s - loss: 109.7453 - val_loss: 88.3469 - 33ms/epoch - 3ms/step
# Epoch 112/200
# 10/10 - 0s - loss: 96.1079 - val_loss: 127.8643 - 16ms/epoch - 2ms/step
# Epoch 113/200
# 10/10 - 0s - loss: 97.6615 - val_loss: 90.5182 - 17ms/epoch - 2ms/step
# Epoch 114/200
# 10/10 - 0s - loss: 96.2431 - val_loss: 106.8562 - 17ms/epoch - 2ms/step
# Epoch 115/200
# 10/10 - 0s - loss: 96.7068 - val_loss: 105.3376 - 32ms/epoch - 3ms/step
# Epoch 116/200
# 10/10 - 0s - loss: 99.8991 - val_loss: 90.6242 - 17ms/epoch - 2ms/step
# Epoch 117/200
# 10/10 - 0s - loss: 98.5037 - val_loss: 88.2684 - 17ms/epoch - 2ms/step
# Epoch 118/200
# 10/10 - 0s - loss: 97.2177 - val_loss: 103.4474 - 17ms/epoch - 2ms/step
# Epoch 119/200
# 10/10 - 0s - loss: 99.8362 - val_loss: 88.2778 - 17ms/epoch - 2ms/step
# Epoch 120/200
# 10/10 - 0s - loss: 94.6362 - val_loss: 89.1479 - 32ms/epoch - 3ms/step
# Epoch 121/200
# 10/10 - 0s - loss: 98.0110 - val_loss: 90.9206 - 16ms/epoch - 2ms/step
# Epoch 122/200
# 10/10 - 0s - loss: 105.3117 - val_loss: 89.9909 - 17ms/epoch - 2ms/step
# Epoch 123/200
# 10/10 - 0s - loss: 96.2083 - val_loss: 95.1810 - 17ms/epoch - 2ms/step
# Epoch 124/200
# 10/10 - 0s - loss: 95.9400 - val_loss: 96.5291 - 32ms/epoch - 3ms/step
# Epoch 125/200
# 10/10 - 0s - loss: 98.9352 - val_loss: 102.2851 - 16ms/epoch - 2ms/step
# Epoch 126/200
# 10/10 - 0s - loss: 97.6249 - val_loss: 88.2805 - 16ms/epoch - 2ms/step
# Epoch 127/200
# 10/10 - 0s - loss: 95.2584 - val_loss: 90.3004 - 17ms/epoch - 2ms/step
# Epoch 128/200
# 10/10 - 0s - loss: 110.8341 - val_loss: 94.5136 - 31ms/epoch - 3ms/step
# Epoch 129/200
# 10/10 - 0s - loss: 99.3995 - val_loss: 98.7997 - 20ms/epoch - 2ms/step
# Epoch 130/200
# 10/10 - 0s - loss: 95.5613 - val_loss: 119.5697 - 16ms/epoch - 2ms/step
# Epoch 131/200
# 10/10 - 0s - loss: 100.6394 - val_loss: 94.5087 - 17ms/epoch - 2ms/step
# Epoch 132/200
# 10/10 - 0s - loss: 96.2350 - val_loss: 105.0021 - 17ms/epoch - 2ms/step
# Epoch 133/200
# 10/10 - 0s - loss: 101.3575 - val_loss: 88.2753 - 33ms/epoch - 3ms/step
# Epoch 134/200
# 10/10 - 0s - loss: 98.2025 - val_loss: 91.5212 - 16ms/epoch - 2ms/step
# Epoch 135/200
# 10/10 - 0s - loss: 96.7807 - val_loss: 113.8622 - 17ms/epoch - 2ms/step
# Epoch 136/200
# 10/10 - 0s - loss: 99.6049 - val_loss: 103.7813 - 17ms/epoch - 2ms/step
# Epoch 137/200
# 10/10 - 0s - loss: 103.9221 - val_loss: 89.2324 - 33ms/epoch - 3ms/step
# Epoch 138/200
# 10/10 - 0s - loss: 95.5578 - val_loss: 95.6691 - 17ms/epoch - 2ms/step
# Epoch 139/200
# 10/10 - 0s - loss: 96.2482 - val_loss: 88.6605 - 17ms/epoch - 2ms/step
# Epoch 140/200
# 10/10 - 0s - loss: 96.0324 - val_loss: 94.2401 - 17ms/epoch - 2ms/step
# Epoch 141/200
# 10/10 - 0s - loss: 101.1188 - val_loss: 91.0717 - 32ms/epoch - 3ms/step
# Epoch 142/200
# 10/10 - 0s - loss: 98.6665 - val_loss: 88.2379 - 16ms/epoch - 2ms/step
# Epoch 143/200
# 10/10 - 0s - loss: 99.8537 - val_loss: 88.7226 - 17ms/epoch - 2ms/step
# Epoch 144/200
# 10/10 - 0s - loss: 99.8261 - val_loss: 109.6642 - 17ms/epoch - 2ms/step
# Epoch 145/200
# 10/10 - 0s - loss: 100.8699 - val_loss: 100.6479 - 20ms/epoch - 2ms/step
# Epoch 146/200
# 10/10 - 0s - loss: 97.0177 - val_loss: 88.9772 - 16ms/epoch - 2ms/step
# Epoch 147/200
# 10/10 - 0s - loss: 95.1206 - val_loss: 89.5316 - 17ms/epoch - 2ms/step
# Epoch 148/200
# 10/10 - 0s - loss: 97.3623 - val_loss: 90.3102 - 31ms/epoch - 3ms/step
# Epoch 149/200
# 10/10 - 0s - loss: 99.0316 - val_loss: 89.5162 - 20ms/epoch - 2ms/step
# Epoch 150/200
# 10/10 - 0s - loss: 101.2322 - val_loss: 93.2767 - 16ms/epoch - 2ms/step
# Epoch 151/200
# 10/10 - 0s - loss: 103.4613 - val_loss: 96.5688 - 17ms/epoch - 2ms/step
# Epoch 152/200
# 10/10 - 0s - loss: 97.4783 - val_loss: 88.3511 - 30ms/epoch - 3ms/step
# Epoch 153/200
# 10/10 - 0s - loss: 96.8409 - val_loss: 92.4011 - 17ms/epoch - 2ms/step
# Epoch 154/200
# 10/10 - 0s - loss: 99.7384 - val_loss: 88.2366 - 21ms/epoch - 2ms/step
# Epoch 155/200
# 10/10 - 0s - loss: 95.3212 - val_loss: 93.6786 - 14ms/epoch - 1ms/step
# Epoch 156/200
# 10/10 - 0s - loss: 97.8333 - val_loss: 88.4596 - 32ms/epoch - 3ms/step
# Epoch 157/200
# 10/10 - 0s - loss: 94.8404 - val_loss: 89.7455 - 17ms/epoch - 2ms/step
# Epoch 158/200
# 10/10 - 0s - loss: 96.4588 - val_loss: 105.1513 - 17ms/epoch - 2ms/step
# Epoch 159/200
# 10/10 - 0s - loss: 100.5571 - val_loss: 89.1905 - 17ms/epoch - 2ms/step
# Epoch 160/200
# 10/10 - 0s - loss: 97.5610 - val_loss: 92.0596 - 20ms/epoch - 2ms/step
# Epoch 161/200
# 10/10 - 0s - loss: 98.2144 - val_loss: 132.4571 - 16ms/epoch - 2ms/step
# Epoch 162/200
# 10/10 - 0s - loss: 105.9152 - val_loss: 88.2460 - 17ms/epoch - 2ms/step
# Epoch 163/200
# 10/10 - 0s - loss: 98.1712 - val_loss: 109.0153 - 30ms/epoch - 3ms/step
# Epoch 164/200
# 10/10 - 0s - loss: 101.3139 - val_loss: 112.4744 - 19ms/epoch - 2ms/step
# Epoch 165/200
# 10/10 - 0s - loss: 97.8546 - val_loss: 89.0666 - 16ms/epoch - 2ms/step
# Epoch 166/200
# 10/10 - 0s - loss: 99.9554 - val_loss: 88.2365 - 17ms/epoch - 2ms/step
# Epoch 167/200
# 10/10 - 0s - loss: 97.4741 - val_loss: 121.3182 - 17ms/epoch - 2ms/step
# Epoch 168/200
# 10/10 - 0s - loss: 105.2432 - val_loss: 122.8024 - 33ms/epoch - 3ms/step
# Epoch 169/200
# 10/10 - 0s - loss: 102.3769 - val_loss: 88.4031 - 18ms/epoch - 2ms/step
# Epoch 170/200
# 10/10 - 0s - loss: 104.5066 - val_loss: 88.5492 - 17ms/epoch - 2ms/step
# Epoch 171/200
# 10/10 - 0s - loss: 99.8107 - val_loss: 88.4100 - 17ms/epoch - 2ms/step
# Epoch 172/200
# 10/10 - 0s - loss: 97.2860 - val_loss: 94.2658 - 32ms/epoch - 3ms/step
# Epoch 173/200
# 10/10 - 0s - loss: 97.8319 - val_loss: 88.8192 - 18ms/epoch - 2ms/step
# Epoch 174/200
# 10/10 - 0s - loss: 98.2780 - val_loss: 141.1793 - 17ms/epoch - 2ms/step
# Epoch 175/200
# 10/10 - 0s - loss: 109.1846 - val_loss: 90.3767 - 17ms/epoch - 2ms/step
# Epoch 176/200
# 10/10 - 0s - loss: 98.9972 - val_loss: 95.5560 - 20ms/epoch - 2ms/step
# Epoch 177/200
# 10/10 - 0s - loss: 96.9907 - val_loss: 98.2552 - 16ms/epoch - 2ms/step
# Epoch 178/200
# 10/10 - 0s - loss: 99.7001 - val_loss: 90.5266 - 17ms/epoch - 2ms/step
# Epoch 179/200
# 10/10 - 0s - loss: 97.5766 - val_loss: 129.6688 - 31ms/epoch - 3ms/step
# Epoch 180/200
# 10/10 - 0s - loss: 112.0769 - val_loss: 88.3592 - 18ms/epoch - 2ms/step
# Epoch 181/200
# 10/10 - 0s - loss: 97.4580 - val_loss: 130.2245 - 17ms/epoch - 2ms/step
# Epoch 182/200
# 10/10 - 0s - loss: 110.9313 - val_loss: 88.3111 - 17ms/epoch - 2ms/step
# Epoch 183/200
# 10/10 - 0s - loss: 98.3372 - val_loss: 89.4223 - 17ms/epoch - 2ms/step
# Epoch 184/200
# 10/10 - 0s - loss: 101.4693 - val_loss: 95.3824 - 19ms/epoch - 2ms/step
# Epoch 185/200
# 10/10 - 0s - loss: 95.2011 - val_loss: 94.7967 - 17ms/epoch - 2ms/step
# Epoch 186/200
# 10/10 - 0s - loss: 97.3794 - val_loss: 88.7045 - 16ms/epoch - 2ms/step
# Epoch 187/200
# 10/10 - 0s - loss: 104.0288 - val_loss: 88.5443 - 17ms/epoch - 2ms/step
# Epoch 188/200
# 10/10 - 0s - loss: 102.8809 - val_loss: 91.2915 - 33ms/epoch - 3ms/step
# Epoch 189/200
# 10/10 - 0s - loss: 96.8824 - val_loss: 92.0359 - 17ms/epoch - 2ms/step
# Epoch 190/200
# 10/10 - 0s - loss: 99.2783 - val_loss: 112.8988 - 16ms/epoch - 2ms/step
# Epoch 191/200
# 10/10 - 0s - loss: 105.8948 - val_loss: 88.3939 - 17ms/epoch - 2ms/step
# Epoch 192/200
# 10/10 - 0s - loss: 97.6856 - val_loss: 100.8580 - 32ms/epoch - 3ms/step
# Epoch 193/200
# 10/10 - 0s - loss: 100.6274 - val_loss: 89.6380 - 18ms/epoch - 2ms/step
# Epoch 194/200
# 10/10 - 0s - loss: 96.7932 - val_loss: 88.2740 - 16ms/epoch - 2ms/step
# Epoch 195/200
# 10/10 - 0s - loss: 100.1695 - val_loss: 88.3155 - 16ms/epoch - 2ms/step
# Epoch 196/200
# 10/10 - 0s - loss: 98.5838 - val_loss: 94.8426 - 19ms/epoch - 2ms/step
# Epoch 197/200
# 10/10 - 0s - loss: 94.6287 - val_loss: 93.5413 - 16ms/epoch - 2ms/step
# Epoch 198/200
# 10/10 - 0s - loss: 100.7240 - val_loss: 91.5447 - 17ms/epoch - 2ms/step
# Epoch 199/200
# 10/10 - 0s - loss: 95.8430 - val_loss: 93.6460 - 17ms/epoch - 2ms/step
# Epoch 200/200
# 10/10 - 0s - loss: 101.1912 - val_loss: 93.7088 - 17ms/epoch - 2ms/step

# %%
non_scale_history.history.keys()
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
train_loss = non_scale_history.history['loss']
vali_loss = non_scale_history.history['val_loss']

# %%
epochs = range(1, len(train_loss)+1)

# %%
plt.plot(epochs, train_loss, '--b', label = 'Trainig')
plt.plot(epochs, vali_loss, '--r', label = 'Validation')
plt.legend()
plt.show()

# %%
non_scale_pred = model.predict(Test_X)

# %%
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_error as mae
from sklearn.metrics import mean_absolute_percentage_error as mape

# %%
non_scaled_2layers_nn_mse = mse(y_true = Test_Y, y_pred = non_scale_pred)
non_scaled_2layers_nn_mae = mae(y_true = Test_Y, y_pred = non_scale_pred)
non_scaled_2layers_nn_mape = mape(y_true = Test_Y, y_pred = non_scale_pred)

# %%
print("Non Scaled 2 Layers Neural Network MSE : {:.3f}".format(non_scaled_2layers_nn_mse))
print("Non Scaled 2 Layers Neural Network MAE : {:.3f}".format(non_scaled_2layers_nn_mae))
print("Non Scaled 2 Layers Neural Network MAPE : {:.3f}".format(non_scaled_2layers_nn_mape))
# Out:
# Non Scaled 2 Layers Neural Network MSE : 61.731
# Non Scaled 2 Layers Neural Network MAE : 5.724
# Non Scaled 2 Layers Neural Network MAPE : 0.297

# %% [markdown]
# ----

# %%
from sklearn.linear_model import LinearRegression as LR

# %%
lr = LR()

# %%
lr.fit(Train_X, Train_Y)
non_scale_LR_pred = lr.predict(Test_X)

# %%
non_scaled_lr_mse = mse(y_true = Test_Y, y_pred = non_scale_LR_pred)
non_scaled_lr_mae = mae(y_true = Test_Y, y_pred = non_scale_LR_pred)
non_scaled_lr_mape = mape(y_true = Test_Y, y_pred = non_scale_LR_pred)

# %%
print("Non Scaled Linear Regression MSE : {:.3f}".format(non_scaled_lr_mse))
print("Non Scaled Linear Regression MAE : {:.3f}".format(non_scaled_lr_mae))
print("Non Scaled Linear Regression MAPE : {:.3f}".format(non_scaled_lr_mape))
# Out:
# Non Scaled Linear Regression MSE : 19.380
# Non Scaled Linear Regression MAE : 3.178
# Non Scaled Linear Regression MAPE : 0.169

# %% [markdown]
# ----

# %% [markdown]
# # Scaled Data로 학습

# %%
tf.random.set_seed(random_seed)
model = keras.Sequential()

model.add(keras.layers.Dense(units = 10, input_shape = (13, ), activation = 'sigmoid'))
model.add(keras.layers.Dense(units = 5, activation = 'sigmoid'))
model.add(keras.layers.Dense(units = 1 , activation = 'linear'))

lr = 0.3
model.compile(loss = 'mse', optimizer = keras.optimizers.SGD(learning_rate = lr))

scale_history = model.fit(Scaled_Train_X, Scaled_Train_Y, batch_size = 32, epochs = 200, shuffle = True, verbose = 2 ,validation_split = 0.2) 
# verbose=0,1,2중 선택
# validation_split -> validation 데이터의 비율을 결정
# Out:
# Epoch 1/200
# 10/10 - 0s - loss: 0.0769 - val_loss: 0.0393 - 211ms/epoch - 21ms/step
# Epoch 2/200
# 10/10 - 0s - loss: 0.0440 - val_loss: 0.0441 - 29ms/epoch - 3ms/step
# Epoch 3/200
# 10/10 - 0s - loss: 0.0423 - val_loss: 0.0395 - 19ms/epoch - 2ms/step
# Epoch 4/200
# 10/10 - 0s - loss: 0.0441 - val_loss: 0.0374 - 15ms/epoch - 1ms/step
# Epoch 5/200
# 10/10 - 0s - loss: 0.0427 - val_loss: 0.0353 - 17ms/epoch - 2ms/step
# Epoch 6/200
# 10/10 - 0s - loss: 0.0397 - val_loss: 0.0344 - 19ms/epoch - 2ms/step
# Epoch 7/200
# 10/10 - 0s - loss: 0.0396 - val_loss: 0.0351 - 21ms/epoch - 2ms/step
# Epoch 8/200
# 10/10 - 0s - loss: 0.0402 - val_loss: 0.0341 - 19ms/epoch - 2ms/step
# Epoch 9/200
# 10/10 - 0s - loss: 0.0388 - val_loss: 0.0344 - 8ms/epoch - 767us/step
# Epoch 10/200
# 10/10 - 0s - loss: 0.0386 - val_loss: 0.0304 - 31ms/epoch - 3ms/step
# Epoch 11/200
# 10/10 - 0s - loss: 0.0383 - val_loss: 0.0311 - 18ms/epoch - 2ms/step
# Epoch 12/200
# 10/10 - 0s - loss: 0.0363 - val_loss: 0.0279 - 16ms/epoch - 2ms/step
# Epoch 13/200
# 10/10 - 0s - loss: 0.0352 - val_loss: 0.0347 - 17ms/epoch - 2ms/step
# Epoch 14/200
# 10/10 - 0s - loss: 0.0363 - val_loss: 0.0336 - 17ms/epoch - 2ms/step
# Epoch 15/200
# 10/10 - 0s - loss: 0.0360 - val_loss: 0.0253 - 32ms/epoch - 3ms/step
# Epoch 16/200
# 10/10 - 0s - loss: 0.0340 - val_loss: 0.0263 - 17ms/epoch - 2ms/step
# Epoch 17/200
# 10/10 - 0s - loss: 0.0315 - val_loss: 0.0273 - 16ms/epoch - 2ms/step
# Epoch 18/200
# 10/10 - 0s - loss: 0.0310 - val_loss: 0.0287 - 17ms/epoch - 2ms/step
# Epoch 19/200
# 10/10 - 0s - loss: 0.0329 - val_loss: 0.0325 - 17ms/epoch - 2ms/step
# Epoch 20/200
# 10/10 - 0s - loss: 0.0307 - val_loss: 0.0220 - 32ms/epoch - 3ms/step
# Epoch 21/200
# 10/10 - 0s - loss: 0.0291 - val_loss: 0.0227 - 17ms/epoch - 2ms/step
# Epoch 22/200
# 10/10 - 0s - loss: 0.0309 - val_loss: 0.0259 - 16ms/epoch - 2ms/step
# Epoch 23/200
# 10/10 - 0s - loss: 0.0294 - val_loss: 0.0181 - 17ms/epoch - 2ms/step
# Epoch 24/200
# 10/10 - 0s - loss: 0.0278 - val_loss: 0.0176 - 17ms/epoch - 2ms/step
# Epoch 25/200
# 10/10 - 0s - loss: 0.0274 - val_loss: 0.0211 - 31ms/epoch - 3ms/step
# Epoch 26/200
# 10/10 - 0s - loss: 0.0303 - val_loss: 0.0262 - 18ms/epoch - 2ms/step
# Epoch 27/200
# 10/10 - 0s - loss: 0.0287 - val_loss: 0.0204 - 16ms/epoch - 2ms/step
# Epoch 28/200
# 10/10 - 0s - loss: 0.0270 - val_loss: 0.0154 - 17ms/epoch - 2ms/step
# Epoch 29/200
# 10/10 - 0s - loss: 0.0264 - val_loss: 0.0149 - 17ms/epoch - 2ms/step
# Epoch 30/200
# 10/10 - 0s - loss: 0.0260 - val_loss: 0.0153 - 32ms/epoch - 3ms/step
# Epoch 31/200
# 10/10 - 0s - loss: 0.0249 - val_loss: 0.0171 - 17ms/epoch - 2ms/step
# Epoch 32/200
# 10/10 - 0s - loss: 0.0307 - val_loss: 0.0197 - 16ms/epoch - 2ms/step
# Epoch 33/200
# 10/10 - 0s - loss: 0.0261 - val_loss: 0.0148 - 17ms/epoch - 2ms/step
# Epoch 34/200
# 10/10 - 0s - loss: 0.0247 - val_loss: 0.0136 - 17ms/epoch - 2ms/step
# Epoch 35/200
# 10/10 - 0s - loss: 0.0231 - val_loss: 0.0179 - 31ms/epoch - 3ms/step
# Epoch 36/200
# 10/10 - 0s - loss: 0.0294 - val_loss: 0.0144 - 17ms/epoch - 2ms/step
# Epoch 37/200
# 10/10 - 0s - loss: 0.0228 - val_loss: 0.0123 - 16ms/epoch - 2ms/step
# Epoch 38/200
# 10/10 - 0s - loss: 0.0225 - val_loss: 0.0120 - 17ms/epoch - 2ms/step
# Epoch 39/200
# 10/10 - 0s - loss: 0.0247 - val_loss: 0.0125 - 17ms/epoch - 2ms/step
# Epoch 40/200
# 10/10 - 0s - loss: 0.0233 - val_loss: 0.0148 - 18ms/epoch - 2ms/step
# Epoch 41/200
# 10/10 - 0s - loss: 0.0228 - val_loss: 0.0116 - 17ms/epoch - 2ms/step
# Epoch 42/200
# 10/10 - 0s - loss: 0.0227 - val_loss: 0.0112 - 16ms/epoch - 2ms/step
# Epoch 43/200
# 10/10 - 0s - loss: 0.0233 - val_loss: 0.0113 - 17ms/epoch - 2ms/step
# Epoch 44/200
# 10/10 - 0s - loss: 0.0221 - val_loss: 0.0332 - 17ms/epoch - 2ms/step
# Epoch 45/200
# 10/10 - 0s - loss: 0.0247 - val_loss: 0.0153 - 32ms/epoch - 3ms/step
# Epoch 46/200
# 10/10 - 0s - loss: 0.0199 - val_loss: 0.0105 - 17ms/epoch - 2ms/step
# Epoch 47/200
# 10/10 - 0s - loss: 0.0194 - val_loss: 0.0127 - 16ms/epoch - 2ms/step
# Epoch 48/200
# 10/10 - 0s - loss: 0.0210 - val_loss: 0.0102 - 17ms/epoch - 2ms/step
# Epoch 49/200
# 10/10 - 0s - loss: 0.0205 - val_loss: 0.0122 - 32ms/epoch - 3ms/step
# Epoch 50/200
# 10/10 - 0s - loss: 0.0215 - val_loss: 0.0130 - 18ms/epoch - 2ms/step
# Epoch 51/200
# 10/10 - 0s - loss: 0.0194 - val_loss: 0.0166 - 16ms/epoch - 2ms/step
# Epoch 52/200
# 10/10 - 0s - loss: 0.0180 - val_loss: 0.0131 - 16ms/epoch - 2ms/step
# Epoch 53/200
# 10/10 - 0s - loss: 0.0185 - val_loss: 0.0098 - 31ms/epoch - 3ms/step
# Epoch 54/200
# 10/10 - 0s - loss: 0.0204 - val_loss: 0.0124 - 19ms/epoch - 2ms/step
# Epoch 55/200
# 10/10 - 0s - loss: 0.0185 - val_loss: 0.0120 - 16ms/epoch - 2ms/step
# Epoch 56/200
# 10/10 - 0s - loss: 0.0251 - val_loss: 0.0120 - 17ms/epoch - 2ms/step
# Epoch 57/200
# 10/10 - 0s - loss: 0.0186 - val_loss: 0.0123 - 17ms/epoch - 2ms/step
# Epoch 58/200
# 10/10 - 0s - loss: 0.0190 - val_loss: 0.0096 - 30ms/epoch - 3ms/step
# Epoch 59/200
# 10/10 - 0s - loss: 0.0232 - val_loss: 0.0184 - 19ms/epoch - 2ms/step
# Epoch 60/200
# 10/10 - 0s - loss: 0.0193 - val_loss: 0.0192 - 16ms/epoch - 2ms/step
# Epoch 61/200
# 10/10 - 0s - loss: 0.0203 - val_loss: 0.0150 - 17ms/epoch - 2ms/step
# Epoch 62/200
# 10/10 - 0s - loss: 0.0198 - val_loss: 0.0088 - 17ms/epoch - 2ms/step
# Epoch 63/200
# 10/10 - 0s - loss: 0.0161 - val_loss: 0.0107 - 31ms/epoch - 3ms/step
# Epoch 64/200
# 10/10 - 0s - loss: 0.0160 - val_loss: 0.0092 - 17ms/epoch - 2ms/step
# Epoch 65/200
# 10/10 - 0s - loss: 0.0185 - val_loss: 0.0101 - 16ms/epoch - 2ms/step
# Epoch 66/200
# 10/10 - 0s - loss: 0.0187 - val_loss: 0.0116 - 18ms/epoch - 2ms/step
# Epoch 67/200
# 10/10 - 0s - loss: 0.0155 - val_loss: 0.0122 - 17ms/epoch - 2ms/step
# Epoch 68/200
# 10/10 - 0s - loss: 0.0188 - val_loss: 0.0174 - 31ms/epoch - 3ms/step
# Epoch 69/200
# 10/10 - 0s - loss: 0.0176 - val_loss: 0.0096 - 18ms/epoch - 2ms/step
# Epoch 70/200
# 10/10 - 0s - loss: 0.0154 - val_loss: 0.0101 - 16ms/epoch - 2ms/step
# Epoch 71/200
# 10/10 - 0s - loss: 0.0188 - val_loss: 0.0109 - 17ms/epoch - 2ms/step
# Epoch 72/200
# 10/10 - 0s - loss: 0.0268 - val_loss: 0.0114 - 17ms/epoch - 2ms/step
# Epoch 73/200
# 10/10 - 0s - loss: 0.0193 - val_loss: 0.0127 - 19ms/epoch - 2ms/step
# Epoch 74/200
# 10/10 - 0s - loss: 0.0217 - val_loss: 0.0140 - 16ms/epoch - 2ms/step
# Epoch 75/200
# 10/10 - 0s - loss: 0.0174 - val_loss: 0.0102 - 16ms/epoch - 2ms/step
# Epoch 76/200
# 10/10 - 0s - loss: 0.0146 - val_loss: 0.0089 - 17ms/epoch - 2ms/step
# Epoch 77/200
# 10/10 - 0s - loss: 0.0154 - val_loss: 0.0141 - 30ms/epoch - 3ms/step
# Epoch 78/200
# 10/10 - 0s - loss: 0.0146 - val_loss: 0.0130 - 18ms/epoch - 2ms/step
# Epoch 79/200
# 10/10 - 0s - loss: 0.0165 - val_loss: 0.0151 - 17ms/epoch - 2ms/step
# Epoch 80/200
# 10/10 - 0s - loss: 0.0145 - val_loss: 0.0087 - 16ms/epoch - 2ms/step
# Epoch 81/200
# 10/10 - 0s - loss: 0.0155 - val_loss: 0.0153 - 17ms/epoch - 2ms/step
# Epoch 82/200
# 10/10 - 0s - loss: 0.0170 - val_loss: 0.0087 - 17ms/epoch - 2ms/step
# Epoch 83/200
# 10/10 - 0s - loss: 0.0166 - val_loss: 0.0088 - 32ms/epoch - 3ms/step
# Epoch 84/200
# 10/10 - 0s - loss: 0.0145 - val_loss: 0.0107 - 17ms/epoch - 2ms/step
# Epoch 85/200
# 10/10 - 0s - loss: 0.0148 - val_loss: 0.0090 - 16ms/epoch - 2ms/step
# Epoch 86/200
# 10/10 - 0s - loss: 0.0153 - val_loss: 0.0136 - 17ms/epoch - 2ms/step
# Epoch 87/200
# 10/10 - 0s - loss: 0.0159 - val_loss: 0.0087 - 17ms/epoch - 2ms/step
# Epoch 88/200
# 10/10 - 0s - loss: 0.0169 - val_loss: 0.0178 - 32ms/epoch - 3ms/step
# Epoch 89/200
# 10/10 - 0s - loss: 0.0153 - val_loss: 0.0112 - 17ms/epoch - 2ms/step
# Epoch 90/200
# 10/10 - 0s - loss: 0.0140 - val_loss: 0.0140 - 16ms/epoch - 2ms/step
# Epoch 91/200
# 10/10 - 0s - loss: 0.0154 - val_loss: 0.0097 - 17ms/epoch - 2ms/step
# Epoch 92/200
# 10/10 - 0s - loss: 0.0137 - val_loss: 0.0179 - 17ms/epoch - 2ms/step
# Epoch 93/200
# 10/10 - 0s - loss: 0.0151 - val_loss: 0.0137 - 31ms/epoch - 3ms/step
# Epoch 94/200
# 10/10 - 0s - loss: 0.0141 - val_loss: 0.0097 - 19ms/epoch - 2ms/step
# Epoch 95/200
# 10/10 - 0s - loss: 0.0139 - val_loss: 0.0086 - 15ms/epoch - 2ms/step
# Epoch 96/200
# 10/10 - 0s - loss: 0.0170 - val_loss: 0.0187 - 17ms/epoch - 2ms/step
# Epoch 97/200
# 10/10 - 0s - loss: 0.0205 - val_loss: 0.0097 - 18ms/epoch - 2ms/step
# Epoch 98/200
# 10/10 - 0s - loss: 0.0133 - val_loss: 0.0112 - 16ms/epoch - 2ms/step
# Epoch 99/200
# 10/10 - 0s - loss: 0.0170 - val_loss: 0.0097 - 19ms/epoch - 2ms/step
# Epoch 100/200
# 10/10 - 0s - loss: 0.0158 - val_loss: 0.0089 - 16ms/epoch - 2ms/step
# Epoch 101/200
# 10/10 - 0s - loss: 0.0134 - val_loss: 0.0113 - 16ms/epoch - 2ms/step
# Epoch 102/200
# 10/10 - 0s - loss: 0.0134 - val_loss: 0.0246 - 16ms/epoch - 2ms/step
# Epoch 103/200
# 10/10 - 0s - loss: 0.0154 - val_loss: 0.0121 - 17ms/epoch - 2ms/step
# Epoch 104/200
# 10/10 - 0s - loss: 0.0157 - val_loss: 0.0120 - 32ms/epoch - 3ms/step
# Epoch 105/200
# 10/10 - 0s - loss: 0.0131 - val_loss: 0.0085 - 18ms/epoch - 2ms/step
# Epoch 106/200
# 10/10 - 0s - loss: 0.0132 - val_loss: 0.0098 - 16ms/epoch - 2ms/step
# Epoch 107/200
# 10/10 - 0s - loss: 0.0132 - val_loss: 0.0162 - 17ms/epoch - 2ms/step
# Epoch 108/200
# 10/10 - 0s - loss: 0.0190 - val_loss: 0.0174 - 17ms/epoch - 2ms/step
# Epoch 109/200
# 10/10 - 0s - loss: 0.0160 - val_loss: 0.0255 - 20ms/epoch - 2ms/step
# Epoch 110/200
# 10/10 - 0s - loss: 0.0172 - val_loss: 0.0086 - 15ms/epoch - 2ms/step
# Epoch 111/200
# 10/10 - 0s - loss: 0.0136 - val_loss: 0.0086 - 17ms/epoch - 2ms/step
# Epoch 112/200
# 10/10 - 0s - loss: 0.0140 - val_loss: 0.0332 - 16ms/epoch - 2ms/step
# Epoch 113/200
# 10/10 - 0s - loss: 0.0201 - val_loss: 0.0086 - 31ms/epoch - 3ms/step
# Epoch 114/200
# 10/10 - 0s - loss: 0.0137 - val_loss: 0.0428 - 19ms/epoch - 2ms/step
# Epoch 115/200
# 10/10 - 0s - loss: 0.0211 - val_loss: 0.0087 - 23ms/epoch - 2ms/step
# Epoch 116/200
# 10/10 - 0s - loss: 0.0129 - val_loss: 0.0093 - 20ms/epoch - 2ms/step
# Epoch 117/200
# 10/10 - 0s - loss: 0.0133 - val_loss: 0.0157 - 20ms/epoch - 2ms/step
# Epoch 118/200
# 10/10 - 0s - loss: 0.0133 - val_loss: 0.0093 - 19ms/epoch - 2ms/step
# Epoch 119/200
# 10/10 - 0s - loss: 0.0130 - val_loss: 0.0095 - 16ms/epoch - 2ms/step
# Epoch 120/200
# 10/10 - 0s - loss: 0.0150 - val_loss: 0.0088 - 16ms/epoch - 2ms/step
# Epoch 121/200
# 10/10 - 0s - loss: 0.0132 - val_loss: 0.0095 - 17ms/epoch - 2ms/step
# Epoch 122/200
# 10/10 - 0s - loss: 0.0127 - val_loss: 0.0104 - 32ms/epoch - 3ms/step
# Epoch 123/200
# 10/10 - 0s - loss: 0.0168 - val_loss: 0.0201 - 17ms/epoch - 2ms/step
# Epoch 124/200
# 10/10 - 0s - loss: 0.0139 - val_loss: 0.0112 - 16ms/epoch - 2ms/step
# Epoch 125/200
# 10/10 - 0s - loss: 0.0138 - val_loss: 0.0086 - 17ms/epoch - 2ms/step
# Epoch 126/200
# 10/10 - 0s - loss: 0.0124 - val_loss: 0.0085 - 17ms/epoch - 2ms/step
# Epoch 127/200
# 10/10 - 0s - loss: 0.0123 - val_loss: 0.0091 - 17ms/epoch - 2ms/step
# Epoch 128/200
# 10/10 - 0s - loss: 0.0142 - val_loss: 0.0086 - 33ms/epoch - 3ms/step
# Epoch 129/200
# 10/10 - 0s - loss: 0.0162 - val_loss: 0.0274 - 16ms/epoch - 2ms/step
# Epoch 130/200
# 10/10 - 0s - loss: 0.0181 - val_loss: 0.0177 - 17ms/epoch - 2ms/step
# Epoch 131/200
# 10/10 - 0s - loss: 0.0161 - val_loss: 0.0139 - 17ms/epoch - 2ms/step
# Epoch 132/200
# 10/10 - 0s - loss: 0.0144 - val_loss: 0.0087 - 17ms/epoch - 2ms/step
# Epoch 133/200
# 10/10 - 0s - loss: 0.0175 - val_loss: 0.0100 - 17ms/epoch - 2ms/step
# Epoch 134/200
# 10/10 - 0s - loss: 0.0158 - val_loss: 0.0099 - 18ms/epoch - 2ms/step
# Epoch 135/200
# 10/10 - 0s - loss: 0.0128 - val_loss: 0.0100 - 16ms/epoch - 2ms/step
# Epoch 136/200
# 10/10 - 0s - loss: 0.0133 - val_loss: 0.0089 - 17ms/epoch - 2ms/step
# Epoch 137/200
# 10/10 - 0s - loss: 0.0130 - val_loss: 0.0095 - 17ms/epoch - 2ms/step
# Epoch 138/200
# 10/10 - 0s - loss: 0.0147 - val_loss: 0.0123 - 17ms/epoch - 2ms/step
# Epoch 139/200
# 10/10 - 0s - loss: 0.0144 - val_loss: 0.0090 - 17ms/epoch - 2ms/step
# Epoch 140/200
# 10/10 - 0s - loss: 0.0150 - val_loss: 0.0100 - 32ms/epoch - 3ms/step
# Epoch 141/200
# 10/10 - 0s - loss: 0.0138 - val_loss: 0.0103 - 17ms/epoch - 2ms/step
# Epoch 142/200
# 10/10 - 0s - loss: 0.0125 - val_loss: 0.0176 - 17ms/epoch - 2ms/step
# Epoch 143/200
# 10/10 - 0s - loss: 0.0150 - val_loss: 0.0095 - 17ms/epoch - 2ms/step
# Epoch 144/200
# 10/10 - 0s - loss: 0.0133 - val_loss: 0.0115 - 17ms/epoch - 2ms/step
# Epoch 145/200
# 10/10 - 0s - loss: 0.0184 - val_loss: 0.0178 - 17ms/epoch - 2ms/step
# Epoch 146/200
# 10/10 - 0s - loss: 0.0146 - val_loss: 0.0126 - 19ms/epoch - 2ms/step
# Epoch 147/200
# 10/10 - 0s - loss: 0.0131 - val_loss: 0.0084 - 17ms/epoch - 2ms/step
# Epoch 148/200
# 10/10 - 0s - loss: 0.0145 - val_loss: 0.0189 - 17ms/epoch - 2ms/step
# Epoch 149/200
# 10/10 - 0s - loss: 0.0146 - val_loss: 0.0093 - 17ms/epoch - 2ms/step
# Epoch 150/200
# 10/10 - 0s - loss: 0.0128 - val_loss: 0.0136 - 17ms/epoch - 2ms/step
# Epoch 151/200
# 10/10 - 0s - loss: 0.0162 - val_loss: 0.0152 - 17ms/epoch - 2ms/step
# Epoch 152/200
# 10/10 - 0s - loss: 0.0140 - val_loss: 0.0101 - 32ms/epoch - 3ms/step
# Epoch 153/200
# 10/10 - 0s - loss: 0.0138 - val_loss: 0.0130 - 17ms/epoch - 2ms/step
# Epoch 154/200
# 10/10 - 0s - loss: 0.0157 - val_loss: 0.0085 - 15ms/epoch - 2ms/step
# Epoch 155/200
# 10/10 - 0s - loss: 0.0123 - val_loss: 0.0085 - 18ms/epoch - 2ms/step
# Epoch 156/200
# 10/10 - 0s - loss: 0.0126 - val_loss: 0.0095 - 17ms/epoch - 2ms/step
# Epoch 157/200
# 10/10 - 0s - loss: 0.0120 - val_loss: 0.0087 - 32ms/epoch - 3ms/step
# Epoch 158/200
# 10/10 - 0s - loss: 0.0141 - val_loss: 0.0106 - 17ms/epoch - 2ms/step
# Epoch 159/200
# 10/10 - 0s - loss: 0.0177 - val_loss: 0.0143 - 17ms/epoch - 2ms/step
# Epoch 160/200
# 10/10 - 0s - loss: 0.0137 - val_loss: 0.0085 - 17ms/epoch - 2ms/step
# Epoch 161/200
# 10/10 - 0s - loss: 0.0120 - val_loss: 0.0083 - 31ms/epoch - 3ms/step
# Epoch 162/200
# 10/10 - 0s - loss: 0.0193 - val_loss: 0.0145 - 19ms/epoch - 2ms/step
# Epoch 163/200
# 10/10 - 0s - loss: 0.0133 - val_loss: 0.0144 - 16ms/epoch - 2ms/step
# Epoch 164/200
# 10/10 - 0s - loss: 0.0140 - val_loss: 0.0104 - 17ms/epoch - 2ms/step
# Epoch 165/200
# 10/10 - 0s - loss: 0.0126 - val_loss: 0.0099 - 30ms/epoch - 3ms/step
# Epoch 166/200
# 10/10 - 0s - loss: 0.0124 - val_loss: 0.0109 - 19ms/epoch - 2ms/step
# Epoch 167/200
# 10/10 - 0s - loss: 0.0130 - val_loss: 0.0085 - 16ms/epoch - 2ms/step
# Epoch 168/200
# 10/10 - 0s - loss: 0.0129 - val_loss: 0.0137 - 16ms/epoch - 2ms/step
# Epoch 169/200
# 10/10 - 0s - loss: 0.0158 - val_loss: 0.0215 - 17ms/epoch - 2ms/step
# Epoch 170/200
# 10/10 - 0s - loss: 0.0149 - val_loss: 0.0104 - 17ms/epoch - 2ms/step
# Epoch 171/200
# 10/10 - 0s - loss: 0.0124 - val_loss: 0.0092 - 32ms/epoch - 3ms/step
# Epoch 172/200
# 10/10 - 0s - loss: 0.0132 - val_loss: 0.0085 - 17ms/epoch - 2ms/step
# Epoch 173/200
# 10/10 - 0s - loss: 0.0149 - val_loss: 0.0082 - 16ms/epoch - 2ms/step
# Epoch 174/200
# 10/10 - 0s - loss: 0.0129 - val_loss: 0.0090 - 17ms/epoch - 2ms/step
# Epoch 175/200
# 10/10 - 0s - loss: 0.0140 - val_loss: 0.0095 - 17ms/epoch - 2ms/step
# Epoch 176/200
# 10/10 - 0s - loss: 0.0123 - val_loss: 0.0141 - 30ms/epoch - 3ms/step
# Epoch 177/200
# 10/10 - 0s - loss: 0.0133 - val_loss: 0.0101 - 19ms/epoch - 2ms/step
# Epoch 178/200
# 10/10 - 0s - loss: 0.0125 - val_loss: 0.0151 - 16ms/epoch - 2ms/step
# Epoch 179/200
# 10/10 - 0s - loss: 0.0167 - val_loss: 0.0088 - 17ms/epoch - 2ms/step
# Epoch 180/200
# 10/10 - 0s - loss: 0.0125 - val_loss: 0.0095 - 17ms/epoch - 2ms/step
# Epoch 181/200
# 10/10 - 0s - loss: 0.0121 - val_loss: 0.0150 - 17ms/epoch - 2ms/step
# Epoch 182/200
# 10/10 - 0s - loss: 0.0155 - val_loss: 0.0087 - 31ms/epoch - 3ms/step
# Epoch 183/200
# 10/10 - 0s - loss: 0.0120 - val_loss: 0.0111 - 18ms/epoch - 2ms/step
# Epoch 184/200
# 10/10 - 0s - loss: 0.0140 - val_loss: 0.0090 - 16ms/epoch - 2ms/step
# Epoch 185/200
# 10/10 - 0s - loss: 0.0120 - val_loss: 0.0158 - 17ms/epoch - 2ms/step
# Epoch 186/200
# 10/10 - 0s - loss: 0.0128 - val_loss: 0.0100 - 30ms/epoch - 3ms/step
# Epoch 187/200
# 10/10 - 0s - loss: 0.0150 - val_loss: 0.0191 - 19ms/epoch - 2ms/step
# Epoch 188/200
# 10/10 - 0s - loss: 0.0209 - val_loss: 0.0082 - 16ms/epoch - 2ms/step
# Epoch 189/200
# 10/10 - 0s - loss: 0.0119 - val_loss: 0.0098 - 17ms/epoch - 2ms/step
# Epoch 190/200
# 10/10 - 0s - loss: 0.0120 - val_loss: 0.0103 - 17ms/epoch - 2ms/step
# Epoch 191/200
# 10/10 - 0s - loss: 0.0143 - val_loss: 0.0083 - 17ms/epoch - 2ms/step
# Epoch 192/200
# 10/10 - 0s - loss: 0.0118 - val_loss: 0.0082 - 31ms/epoch - 3ms/step
# Epoch 193/200
# 10/10 - 0s - loss: 0.0133 - val_loss: 0.0085 - 18ms/epoch - 2ms/step
# Epoch 194/200
# 10/10 - 0s - loss: 0.0125 - val_loss: 0.0111 - 17ms/epoch - 2ms/step
# Epoch 195/200
# 10/10 - 0s - loss: 0.0151 - val_loss: 0.0085 - 17ms/epoch - 2ms/step
# Epoch 196/200
# 10/10 - 0s - loss: 0.0137 - val_loss: 0.0267 - 17ms/epoch - 2ms/step
# Epoch 197/200
# 10/10 - 0s - loss: 0.0156 - val_loss: 0.0081 - 31ms/epoch - 3ms/step
# Epoch 198/200
# 10/10 - 0s - loss: 0.0121 - val_loss: 0.0090 - 19ms/epoch - 2ms/step
# Epoch 199/200
# 10/10 - 0s - loss: 0.0122 - val_loss: 0.0082 - 17ms/epoch - 2ms/step
# Epoch 200/200
# 10/10 - 0s - loss: 0.0139 - val_loss: 0.0102 - 16ms/epoch - 2ms/step

# %%
scale_pred = model.predict(Scaled_Test_X)

# %%
scale_pred = scaler_Y.inverse_transform(scale_pred)

# %%
scaled_2layers_nn_mse = mse(y_true = Test_Y, y_pred = scale_pred)
scaled_2layers_nn_mae = mae(y_true = Test_Y, y_pred = scale_pred)
scaled_2layers_nn_mape = mape(y_true = Test_Y, y_pred = scale_pred)

# %%
print("Scaled 2 Layers Neural Network MSE : {:.3f}".format(scaled_2layers_nn_mse))
print("Scaled 2 Layers Neural Network MAE : {:.3f}".format(scaled_2layers_nn_mae))
print("Scaled 2 Layers Neural Network MAPE : {:.3f}".format(scaled_2layers_nn_mape))
# Out:
# Scaled 2 Layers Neural Network MSE : 22.101
# Scaled 2 Layers Neural Network MAE : 3.648
# Scaled 2 Layers Neural Network MAPE : 0.191
